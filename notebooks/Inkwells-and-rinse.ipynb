# %%
from pt import AxiDrawPlotter, MPLMockPlotter, Studio, Vec2, Canvas, BrushCleaner

# %%
# plotter = AxiDrawPlotter()
# plotter.align()

# %%
plotter = MPLMockPlotter()

# %%
studio = Studio(plotter, bbox=(Vec2(0, 0), Vec2(10, 7)))
studio.add_object(Canvas(Vec2(6, 4), Vec2(4, 1), Vec2(4 + 4, 1 + 6)), name="canvas")
studio.add_object(BrushCleaner(Vec2(1, 1), 1.1), name="waterwell")

# %%
studio.waterwell_clean()

# %%
studio.debug_draw()
